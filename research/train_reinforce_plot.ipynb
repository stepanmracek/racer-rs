# %%
from matplotlib import pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("train_reinforce2.log", names=("episode", "reward", "running_mean_reward"))
display(data)
# Out:
#       episode    reward  running_mean_reward
# 0           1   3253.44               172.17
# 1           2     75.28               167.33
# 2           3   -726.35               122.64
# 3           4   1677.98               200.41
# 4           5   1096.80               245.23
# ...       ...       ...                  ...
# 5836     5837    -78.42              5265.35
# 5837     5838   2893.53              5146.76
# 5838     5839  14246.16              5601.73
# 5839     5840   9953.69              5819.33
# 5840     5841   3719.99              5714.36
#
# [5841 rows x 3 columns]

# %%
plt.plot(data.episode, data.reward, alpha=0.5)
plt.plot(data.episode, data.running_mean_reward)
plt.show()
