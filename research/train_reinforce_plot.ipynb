# %%
from matplotlib import pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("train_reinforce2.log", names=("episode", "reward", "running_mean_reward"))
display(data)
# Out:
#        episode    reward  running_mean_reward
# 0            1   3253.44               172.17
# 1            2     75.28               167.33
# 2            3   -726.35               122.64
# 3            4   1677.98               200.41
# 4            5   1096.80               245.23
# ...        ...       ...                  ...
# 44071    44072   4506.59              8380.23
# 44072    44073  16039.75              8763.21
# 44073    44074   1570.42              8403.57
# 44074    44075   2834.56              8125.12
# 44075    44076   1001.17              7768.92
#
# [44076 rows x 3 columns]

# %%
plt.plot(data.episode, data.reward, alpha=0.5)
plt.plot(data.episode, data.running_mean_reward)
plt.show()
